# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxouuu4/test_git/blob/main/math0487_nb0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📓 Notebook 0 : **Introduction et consignes**
#
# ## Bienvenue ! 👋
#
# Cette année, le staff de MATH0487 a décidé de mettre à votre disposition des notebooks Jupyter interactifs, hébergés par Google Colab.
#
# Ces notebooks sont constitués de cellules de texte 📖 (utilisant le langage Markdown), double-cliquez pour voir le texte brut :

# %% [markdown]
# Hello, je suis une cellule de texte ! J'offre de nombreuses options de traitement de texte, telles que
# - la mise en **gras**
# - ou en *italique*
# - la syntaxe LaTeX, $Y \sim \mathcal{N}(0, 1)$
# - les listes à puces,
# - etc.

# %% [markdown]
# Et des cellules de code 💻 exécutable (utilisant le langage Python):

# %%
# appuie sur "Play" ou "Maj + Enter" pour m'exécuter !
import numpy as np

my_arr = np.array([1, 2, 3])
print(my_arr**2)
# Out:
# [1 4 9]

# %% [markdown]
#  Certaines cellules de texte vous demande d'interagir avec le notebook, et/ou pose certaines questions ouvertes. En manipulant les curseurs, bouttons, etc, vous pouvez tenter de répondre à ces questions dans les cellules vides prévues à cet effet. Évidemment, le but ici étant de renforcer votre compréhension de la matière par la manipulation de données concrètes, nous vous encourageons à ne pas utiliser Gemini qui est intégré dans Colab, ou un autre outil IA.

# %% [markdown]
# ## Délivrables 🚚
#
# Vous pouvez réaliser ces notebooks par groupe d'autant d'étudiants que vous le désirez. Chaque groupe *peut* rendre une version complétée sur Gradescope, sous la forme d'un fichier `.ipynb` **où toutes les cellules sont exécutées**, s'il désire recevoir un feedback. Ce n'est pas obligatoire, mais fortement encouragé.
#
# _N.B._ : Pour sauvegarder un notebook modifié, vous devez en créer une copie personnelle (`File -> Save a copy ...`).
#
# La date limite de soumission dépend du notebook, et est visible sur Gradescope. Jusqu'à cette date, vous avez la possibilité de (re)soumettre votre notebook autant de fois que vous le souhaitez. Au-delà de cette date, il ne sera plus possible de le soumettre. N'attendez pas la dernière minute pour soumettre une première version de votre travail !

# %% [markdown]
# ## Questions ❓
#
# Toutes vos questions sur ces notebooks (y compris sur l'utilisation de Python ou de Jupyter) doivent être posées sur le forum [Ed Discussion](https://edstem.org/eu/courses/2455/discussion).

# %% [markdown]
# ## À vous de jouer ! 🚀
#
# Voilà, vous avez (déjà) pris connaissance de toutes les instructions nécessaires. À vous désormais de prendre en main cet outil pour explorer de manière interactive la matière du cours ! Bon travail ! 💪
